# %% [markdown]
# ## Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %pwd
# %cd drive/My Drive
# %pwd
# Out:
# /content/drive/My Drive
# '/content/drive/My Drive'

# %%
# %ls -ltr
# Out:
# total 225
# drwx------ 2 root root   4096 Nov 25 19:46 'Recipes - Annotated'/
# drwx------ 2 root root   4096 Nov 27 03:48  Auto_annotated_recipes/
# drwx------ 2 root root   4096 Nov 27 03:57  annotation_code/
# drwx------ 2 root root   4096 Nov 29 23:10 'Colab Notebooks'/
# drwx------ 2 root root   4096 Nov 30 02:39  NER_code/
# drwx------ 2 root root   4096 Nov 30 05:40  Recipes_annotated_python/
# drwx------ 2 root root   4096 Nov 30 23:21 'Final Recipes corpus'/
# drwx------ 2 root root   4096 Dec  6 03:01  Recipes_annotated_java_1/
# drwx------ 2 root root   4096 Dec  6 18:10 'Anyfile Notepad Files'/
# drwx------ 2 root root   4096 Dec  6 19:24 'Recipes from allrecipes.com'/
# -rw------- 1 root root  26489 Dec  9 06:03 'ELMO with LSTM (1).png'
# drwx------ 2 root root   4096 Dec 10 17:18  shilsi_test/
# drwx------ 2 root root   4096 Dec 17 20:00  final_recipe_corpus_annotated/
# -rw------- 1 root root  26485 Dec 18 03:21 'ELMO with LSTM.png'
# -rw------- 1 root root 122995 Dec 18 05:33  NER_with_ELMO.ipynb
# drwx------ 2 root root   4096 Dec 18 21:50  ANLP-Final-Project-Submission/

# %% [markdown]
# ## Importing Libraries

# %%
# Imports go here
import numpy as np
import pandas as pd
import os
import glob
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras import layers
from sklearn.preprocessing import LabelBinarizer
from keras.layers import Activation, Dense, Dropout
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# ## File Directories

# %%
# Read the labeled conell files with the tag for an ingredient as B-OTH and prepare output sequence Y:
connll_directory  = '/content/drive/My Drive/ANLP-Final-Project-Submission/recipe_corpus_annotated_32/'
connll_directory1 = '/content/drive/My Drive//ANLP-Final-Project-Submission/recipe_corpus_annotated_469/'

# %% [markdown]
# ## Funtion to find ingredients from annotated recipe and return array of ingredients

# %%
def ingredient_finder(text):
  content = open(text,'r')
  tagmaps = {}
  ing=[]
  try:
    for line in content:
        words = line.strip().split(" ")
        if(words[1] == "B-OTH" and words[0] not in tagmaps.keys()):
            tagmaps[words[0]] = words[1]
            ing.append(str(words[0]))

    ingredientlables.append(tagmaps)
  except: 
    print(text)
  return ing

# %% [markdown]
# ## Funtion to find ingredients from annotated recipe and return array of ingredients

# %%
os.chdir(connll_directory )
files_labeled = [f for f in os.listdir(connll_directory)]

# %%
food_df=pd.DataFrame(files_labeled)
food_df.columns = ['Recipe_file']
food_df['Recipe']=food_df['Recipe_file']
food_df['Recipe']=food_df['Recipe'].str.split('.',n=1,expand=True)

food_df
# Out:
#                                     Recipe_file                                   Recipe
# 0                  asparagus-pistachio-soup.txt                 asparagus-pistachio-soup
# 1                           aubergine_puree.txt                          aubergine_puree
# 2                              clam_chowder.txt                             clam_chowder
# 3                         easy_pumpkin_soup.txt                        easy_pumpkin_soup
# 4         beans_midly_spiced_and_stir-fried.txt        beans_midly_spiced_and_stir-fried
# 5                                    dolmeh.txt                                   dolmeh
# 6                     easy_microwave_tomato.txt                    easy_microwave_tomato
# 7     easy_grilled_leeks_with_grated_cheese.txt    easy_grilled_leeks_with_grated_cheese
# 8   basque-style_cream_mushroom_soup_saveur.txt  basque-style_cream_mushroom_soup_saveur
# 9                            grilled_onions.txt                           grilled_onions
# 10                                   kimchi.txt                                   kimchi
# 11                 healthy_asian_apple_soup.txt                 healthy_asian_apple_soup
# 12                 hot_and_sour_shrimp_soup.txt                 hot_and_sour_shrimp_soup
# 13                             lettuce_soup.txt                             lettuce_soup
# 14                   hot_and_sour_cucumbers.txt                   hot_and_sour_cucumbers
# 15                                   hoomos.txt                                   hoomos
# 16                               kapustniak.txt                               kapustniak
# 17                                   latkes.txt                                   latkes
# 18             kapustnica_sour_cabbage_soup.txt             kapustnica_sour_cabbage_soup
# 19                                  madjara.txt                                  madjara
# 20                                    mango.txt                                    mango
# 21                              oyster_stew.txt                              oyster_stew
# 22                   reasted_red_onion_soup.txt                   reasted_red_onion_soup
# 23                mechthilds_sweet_potatoes.txt                mechthilds_sweet_potatoes
# 24              sopa_de_carbasso_bercelonia.txt              sopa_de_carbasso_bercelonia
# 25                      potato-turnip_balls.txt                      potato-turnip_balls
# 26                monastery_style_bean_soup.txt                monastery_style_bean_soup
# 27                          quick_and_dirty.txt                          quick_and_dirty
# 28                  southwestern_onion_soup.txt                  southwestern_onion_soup
# 29                       stuffed_aubergines.txt                       stuffed_aubergines
# 30      stuffed_peppers_with_egg_and_cheese.txt      stuffed_peppers_with_egg_and_cheese
# 31                    sweet_red_pepper_soup.txt                    sweet_red_pepper_soup

# %%
ingredient_finder('clam_chowder.txt')
# Out:
# clam_chowder.txt
# ['potatoes',
#  'potato',
#  'floury',
#  'boiled',
#  'bacon',
#  'pork',
#  'onion',
#  'thyme',
#  'peppercorns',
#  'paprika',
#  'butter',
#  'cornmeal',
#  'corn',
#  'notice',
#  'nicer',
#  'appearance',
#  'leafless',
#  'shells',
#  'juices',
#  'oils',
#  'leaflets',
#  'bread',
#  'salad']

# %% [markdown]
# ## Funtion to find ingredients from annotated recipe and return array of ingredients

# %%
food_df['Ingredients'] = food_df['Recipe_file'].apply(lambda x: ingredient_finder(x))
# Out:
# asparagus-pistachio-soup.txt
# aubergine_puree.txt
# clam_chowder.txt
# easy_pumpkin_soup.txt
# beans_midly_spiced_and_stir-fried.txt
# dolmeh.txt
# easy_microwave_tomato.txt
# easy_grilled_leeks_with_grated_cheese.txt
# basque-style_cream_mushroom_soup_saveur.txt
# grilled_onions.txt
# kimchi.txt
# healthy_asian_apple_soup.txt
# hot_and_sour_shrimp_soup.txt
# lettuce_soup.txt
# hot_and_sour_cucumbers.txt
# hoomos.txt
# kapustniak.txt
# latkes.txt
# kapustnica_sour_cabbage_soup.txt
# madjara.txt
# mango.txt
# oyster_stew.txt
# reasted_red_onion_soup.txt
# mechthilds_sweet_potatoes.txt
# sopa_de_carbasso_bercelonia.txt
# potato-turnip_balls.txt
# monastery_style_bean_soup.txt
# quick_and_dirty.txt
# southwestern_onion_soup.txt
# stuffed_aubergines.txt
# stuffed_peppers_with_egg_and_cheese.txt
# sweet_red_pepper_soup.txt

# %%
food_df
# Out:
#                                     Recipe_file  ...                                        Ingredients
# 0                  asparagus-pistachio-soup.txt  ...  [soup, salt, salted, pistachios, butter, salty...
# 1                           aubergine_puree.txt  ...  [aubergine, aubergines, peppers, tomatoes, clo...
# 2                              clam_chowder.txt  ...  [potatoes, potato, floury, boiled, bacon, pork...
# 3                         easy_pumpkin_soup.txt  ...                               [pumpkin, butternut]
# 4         beans_midly_spiced_and_stir-fried.txt  ...  [beans, spiced, turmeric, powder, curry, leave...
# 5                                    dolmeh.txt  ...  [leaf, leaves, rice, peas, sugar, sabzi, herbs...
# 6                     easy_microwave_tomato.txt  ...                                           [tomato]
# 7     easy_grilled_leeks_with_grated_cheese.txt  ...                       [leeks, cheese, olive, boil]
# 8   basque-style_cream_mushroom_soup_saveur.txt  ...  [creamy, mushroom, mushrooms, portobello, porc...
# 9                            grilled_onions.txt  ...                                             [lime]
# 10                                   kimchi.txt  ...                [ginger, saucer, cheesecloth, nice]
# 11                 healthy_asian_apple_soup.txt  ...                 [apple, apples, pears, pearl, ham]
# 12                 hot_and_sour_shrimp_soup.txt  ...                [shrimp, soups, fish, sauce, shell]
# 13                             lettuce_soup.txt  ...        [lettuce, ham, creme, eggs, creamy, nicely]
# 14                   hot_and_sour_cucumbers.txt  ...  [cucumbers, sauce, noodles, sugar, seed, cucum...
# 15                                   hoomos.txt  ...                       [tahiini, garbanzos, sesame]
# 16                               kapustniak.txt  ...               [rolls, veggies, cabbage, vegetable]
# 17                                   latkes.txt  ...               [applesauce, pepper, pancakes, beer]
# 18             kapustnica_sour_cabbage_soup.txt  ...  [cakes, cake, paprika, sausage, grains, sausag...
# 19                                  madjara.txt  ...                                   [lentils, water]
# 20                                    mango.txt  ...                        [mango, mayonnaise, mangos]
# 21                              oyster_stew.txt  ...                            [oysters, milk, boiler]
# 22                   reasted_red_onion_soup.txt  ...                       [onion, foil, coating, coat]
# 23                mechthilds_sweet_potatoes.txt  ...            [potatoes, vanilla, pecans, cornflakes]
# 24              sopa_de_carbasso_bercelonia.txt  ...                                        [disappear]
# 25                      potato-turnip_balls.txt  ...                [turnips, turnip, lemons, breading]
# 26                monastery_style_bean_soup.txt  ...                     [bean, chillies, choice, mint]
# 27                          quick_and_dirty.txt  ...                                             [coil]
# 28                  southwestern_onion_soup.txt  ...  [brigham, chilies, coriander, chipotle, pepper...
# 29                       stuffed_aubergines.txt  ...                             [breadcrumbs, peppers]
# 30      stuffed_peppers_with_egg_and_cheese.txt  ...                                              [egg]
# 31                    sweet_red_pepper_soup.txt  ...                                    [broiler, seed]
#
# [32 rows x 3 columns]

# %% [markdown]
# ## Reading files from another directory and following the same process as above

# %%
os.chdir(connll_directory1 )
files_labeled1 = [f for f in os.listdir(connll_directory1)]
food_df1=pd.DataFrame(files_labeled1)
food_df1.columns = ['Recipe_file']
food_df1['Recipe']=food_df1['Recipe_file']
food_df1['Recipe']=food_df1['Recipe'].str.split('.',n=1,expand=True)

food_df1
# Out:
#                                     Recipe_file                                  Recipe
# 0           15-Minute Dinner Nachos Supreme.txt         15-Minute Dinner Nachos Supreme
# 1                         Antipasto Squares.txt                       Antipasto Squares
# 2    Annie_s Fruit Salsa and Cinnamon Chips.txt  Annie_s Fruit Salsa and Cinnamon Chips
# 3                Amy_s Cilantro Cream Sauce.txt              Amy_s Cilantro Cream Sauce
# 4                     Apple Breakfast Bread.txt                   Apple Breakfast Bread
# ..                                          ...                                     ...
# 464               Yeast-Free Cinnamon Rolls.txt               Yeast-Free Cinnamon Rolls
# 465                          Yummy Roll Ups.txt                          Yummy Roll Ups
# 466            Yummy Sweet Potato Casserole.txt            Yummy Sweet Potato Casserole
# 467                       Zucchini Bread IV.txt                       Zucchini Bread IV
# 468                          Zucchini Bread.txt                          Zucchini Bread
#
# [469 rows x 2 columns]

# %%
food_df1['Ingredients'] = food_df1['Recipe_file'].apply(lambda x: ingredient_finder(x))
# Out:
# 15-Minute Dinner Nachos Supreme.txt
# Antipasto Squares.txt
# Annie_s Fruit Salsa and Cinnamon Chips.txt
# Amy_s Cilantro Cream Sauce.txt
# Apple Breakfast Bread.txt
# Ali_s Amazing Bruschetta.txt
# Amazing Muffin Cups.txt
# Apple Crisp II.txt
# All-Around Good Smoothie.txt
# 4H Banana Bread.txt
# Apple Dip.txt
# Arlene_s Bacon _ Crabmeat.txt
# Artichoke _ Spinach Dip Restaurant Style.txt
# Artichoke Spinach Dip.txt
# Artichoke Bruschetta.txt
# Asian Lettuce Wraps.txt
# Apple Pie by Grandma Ople.txt
# Apple-Raisin French Toast Casserole.txt
# Arizona Hatch Chili.txt
# Apple Raisin French Toast Strata.txt
# Asparagus Quiche.txt
# Awesome Sausage, Apple and Cranberry Stuffing.txt
# Avocado Corn Salsa.txt
# B and L_s Strawberry Smoothie.txt
# Baby Spinach Omelet.txt
# Awesome and Easy Creamy Corn Casserole.txt
# Avocado, Tomato and Mango Salsa.txt
# Baby BLT.txt
# Baba Ghanoush.txt
# Avocado Feta Salsa.txt
# Bacon and Cheddar Stuffed Mushrooms.txt
# Bacon Quiche Tarts.txt
# Bacon Wrapped Barbeque Shrimp.txt
# Bacon and Tomato Cups.txt
# Bacon for the Family or a Crowd.txt
# Bacon Wrapped Dates Stuffed with Blue Cheese.txt
# Bacon-Wrapped Jalapeno Poppers.txt
# Bacon Water Chestnut Rolls.txt
# Bacon Wrapped Smokies.txt
# Bacon Cheddar Deviled Eggs.txt
# Baked Denver Omelet.txt
# Baked Omelet.txt
# Baked Oatmeal II.txt
# Baked Pork Spring Rolls.txt
# Baked Omelet Squares.txt
# Baked Omelet Roll.txt
# Baked Ham and Cheese Party Sandwiches.txt
# Baked French Toast.txt
# Baked Oatmeal I.txt
# Baked Kale Chips.txt
# Baked Tortilla Chips.txt
# Banana Bread.txt
# Banana Nut Bread II.txt
# Banana Bread - Quick Bread for Machines.txt
# Banana Banana Bread.txt
# Balsamic Bruschetta.txt
# Banana Peanut Butter Bread.txt
# Banana Nut Bread I.txt
# Banana Crepes.txt
# Banana Pancakes I.txt
# Banana Sour Cream Bread.txt
# Ba_corn Cheese Corn .txt
# Best Brownies.txt
# Best Bruschetta Ever.txt
# Best Big, Fat, Chewy Chocolate Chip Cookie.txt
# Best Egg Rolls.txt
# Beef Stew VI.txt
# Best Chocolate Chip Cookies.txt
# Basic Crepes.txt
# Basic Mashed Potatoes.txt
# Best Ever Jalapeno Poppers.txt
# BLT Dip.txt
# Blooming Onion and Dipping Sauce.txt
# Best Guacamole.txt
# Best Green Bean Casserole.txt
# Best Potatoes You_ll Ever Taste.txt
# Better-Than-Olive Garden® Alfredo Sauce .txt
# Black Bean Hummus.txt
# Best Spinach Dip Ever.txt
# Best Ever Slow Cooker Italian Beef Roast.txt
# Blue Bacon Stuffed Mushrooms.txt
# Brown Sugar Banana Nut Bread I.txt
# Breakfast Pies.txt
# Brown Sugar Smokies.txt
# Boilermaker Tailgate Chili.txt
# Broiled Grapefruit.txt
# Breakfast Casserole II.txt
# Breakfast Casserole III.txt
# Blueberry French Toast.txt
# Brie Cheese Appetizer.txt
# Brunch Enchiladas.txt
# Buttermilk Pancakes II.txt
# Buttermilk Pancakes I.txt
# Butter Flaky Pie Crust.txt
# Brussels Sprouts Gratin.txt
# Candied Pecans .txt
# Candied Almonds.txt
# Candied Yams.txt
# Candy Coated Pecans.txt
# Caramel Apple Pork Chops.txt
# Caramel Snack Mix.txt
# Cheesy Amish Breakfast Casserole.txt
# Cathy_s Banana Bread.txt
# Cheese Fondue.txt
# Cheddar Bay Biscuits.txt
# Charleston Breakfast Casserole.txt
# Cheesy Broccoli-Stuffed Chicken Breasts.txt
# Cheesy Ham and Hash Brown Casserole.txt
# Carla_s Fruit Dip.txt
# Cheese Ball I.txt
# Cheesy Sausage Lasagna Soup.txt
# Chicago Dip.txt
# Chef John_s Pumpkin Pancakes.txt
# Chef John_s Baked Eggs.txt
# Chef John_s Shepherd_s Pie.txt
# Chef John_s Banana Bread.txt
# Chef John_s Quiche Lorraine.txt
# Chef John_s Make-Ahead Turkey Gravy.txt
# Chef John_s Pumpkin Pie.txt
# Chewy Granola Bars.txt
# Chocolate Chip Cheese Ball.txt
# Christmas Brunch Casserole.txt
# Cinnamon Bread I.txt
# Chocolate Wave Zucchini Bread.txt
# Christmas Breakfast Pizza.txt
# Christmas Breakfast Sausage Casserole.txt
# Chocolate Eclair Cake.txt
# Chocolate Chip Orange Zucchini Bread.txt
# Chocolate Kahlua® Cake.txt
# Chunky Monkey Pancakes.txt
# Cinnamon Griddle Cakes.txt
# Cocktail Meatballs I.txt
# Clark_s Quiche.txt
# Classic Waffles.txt
# Cocktail Meatballs.txt
# Cinnamon Swirl Bread.txt
# Cinnamon Raisin Bread I.txt
# Coconut Shrimp I.txt
# Country Breakfast Casserole.txt
# Corn Fritters.txt
# Country Quiche.txt
# Crab Stuffed Mushrooms.txt
# Country Style Fried Potatoes.txt
# Cranberry Orange Rolls.txt
# Crab Rangoon III.txt
# Cranberry Sauce.txt
# Crab and Swiss Quiche.txt
# Crab Quiche.txt
# Crab Quiche I.txt
# Crab Dip.txt
# Cream Cheese Penguins.txt
# Crepes.txt
# Creme Brulee French Toast.txt
# Creamy Strawberry Crepes.txt
# Crock Pot® Party Meatballs.txt
# Creamy Dill Cucumber Toasties.txt
# Creamy Cornbread Casserole .txt
# Creamy Mushroom Meatloaf.txt
# Creamy Banana Bread.txt
# Cream Corn Like No Other.txt
# Crustless Spinach Quiche.txt
# Deviled Eggs II.txt
# Danish Kringle.txt
# Deviled Eggs I.txt
# Delicious Pumpkin Bread.txt
# Dawn_s Candied Walnuts.txt
# Delicious Ham and Potato Soup.txt
# Dill Dip III.txt
# Deviled Eggs.txt
# Dessert Crepes.txt
# Dinah_s Stuffed Mushrooms.txt
# Double Layer Pumpkin Cheesecake.txt
# Dip For The Stars.txt
# Dutch Babies II.txt
# D_s Famous Salsa.txt
# Di_s Delicious Deluxe Deviled Eggs.txt
# Dominican Style Oatmeal.txt
# Downeast Maine Pumpkin Bread.txt
# Divine Hard-Boiled Eggs.txt
# Double Tomato Bruschetta.txt
# Easter Breakfast Casserole.txt
# Easy Bacon and Cheese Quiche.txt
# Easy Meatloaf.txt
# Easy Cheese Ball II.txt
# Easy Granola Bars.txt
# Easy Pancakes.txt
# Easy Guacamole.txt
# Easy Hummus.txt
# Easy Banana Bread.txt
# Easy Homemade Pie Crust.txt
# Easy Quiche Lorraine.txt
# Easy Sausage Gravy and Biscuits.txt
# Egg and Sausage Casserole.txt
# Easy Quiche.txt
# Easy Roasted Red Pepper Hummus.txt
# Easy Spicy Roasted Potatoes.txt
# Eggs Benedict.txt
# Easy Sausage Strata.txt
# Egg in a Hole.txt
# Eggs Benedict Casserole.txt
# Emma_s Belgian Waffles.txt
# Fast and Easy Pancakes.txt
# Favorite Banana Blueberry Quick Bread.txt
# Florentine Artichoke Dip.txt
# Farmer_s Casserole.txt
# Espinacas con Garbanzos (Spinach with Garbanzo Beans).txt
# Fluffy Canadian Pancakes.txt
# Extra Easy Hummus.txt
# Fluffy and Delicious Pancakes.txt
# Feta Cheese Foldovers.txt
# Fluffy French Toast.txt
# French Toast II.txt
# French Toast I.txt
# French Toast Casserole.txt
# Fluffy Pancakes.txt
# Fresh Tomato Salsa.txt
# French Toast Souffle.txt
# French Onion Casserole.txt
# Fried Cabbage with Bacon, Onion, and Garlic.txt
# French Crepes.txt
# Fried Mozzarella Cheese Sticks.txt
# German Pancakes II.txt
# German Potato Pancakes.txt
# Grain and Nut Whole Wheat Pancakes.txt
# Good Old Fashioned Pancakes.txt
# Gingerbread Waffles with Hot Chocolate Sauce.txt
# Gary_s Stuffed Mushrooms.txt
# Fruit Dip II.txt
# German Apple Pancake.txt
# Gourmet Sweet Potato Classic.txt
# Grandad_s Pancakes.txt
# Grandma_s Green Bean Casserole.txt
# Great Garlic Bread.txt
# Grilled Marinated Shrimp.txt
# Grandmother_s Buttermilk Cornbread.txt
# Granola Bars III.txt
# Grandma_s Peach French Toast.txt
# Grandma_s Corn Bread Dressing.txt
# Grandpa_s Classic Coney Sauce.txt
# Grilled Bacon Jalapeno Wraps.txt
# Grilled Portobello Mushrooms.txt
# Hash Brown and Egg Casserole.txt
# Hash Brown Quiche.txt
# Groovy Green Smoothie.txt
# Grilled Shrimp Scampi.txt
# Guacamole.txt
# Healthier Mediterranean Tuna Salad.txt
# Hamburger Steak with Onions and Gravy.txt
# Ham and Cheese Breakfast Quiche.txt
# Ham and Cheese Quiche.txt
# Heather_s Cilantro, Black Bean, and Corn Salsa.txt
# Honey Nut Granola.txt
# Homemade Butter.txt
# Hot Artichoke and Spinach Dip II.txt
# Hot Artichoke Spinach Dip.txt
# Hot Bean Dip.txt
# Home-Fried Potatoes.txt
# Hot Crab Dip.txt
# Honey Butter.txt
# Honey Mustard Sauce.txt
# Hot Mexican Spinach Dip.txt
# Irresistible Irish Soda Bread.txt
# Individual Baked Eggs.txt
# Hummus III.txt
# Hot Pizza Dip.txt
# Irish Soda Bread I.txt
# Instant Pot® Turkey Breast.txt
# Italian Sausage Soup with Tortellini.txt
# Hungarian Mushroom Soup.txt
# How to Cook a Turkey.txt
# Jalapeno Popper Spread.txt
# Joy_s Easy Banana Bread.txt
# Juicy Thanksgiving Turkey.txt
# Janet_s Rich Banana Bread.txt
# Joseph_s Best Easy Bacon Recipe.txt
# Kielbasa and Potato Bake.txt
# Jalapeno Poppers I.txt
# Ken_s Perfect Hard Boiled Egg (And I Mean Perfect).txt
# Kettle Corn.txt
# Jimmy Dean Breakfast Casserole.txt
# Kielbasa with Brussels Sprouts.txt
# Libby_s® Famous Pumpkin Pie.txt
# Lower Fat Banana Bread I.txt
# Louisiana Sweet Potato Pancakes.txt
# Lower Fat Banana Bread II.txt
# Light and Fluffy Spinach Quiche.txt
# Lana_s Sweet and Sour Meatballs.txt
# Loaded Crack Potatoes.txt
# Lola_s Horchata.txt
# King Crab Appetizers.txt
# Luscious Spinach Artichoke Dip.txt
# Megan_s Granola.txt
# Make Ahead Breakfast Casserole.txt
# Mango Salsa.txt
# Make-Ahead Turkey Gravy.txt
# Maple Apple Turkey Sausage.txt
# Maryland Crab Cakes II.txt
# Mary_s Roasted Red Pepper Dip.txt
# Mexican Cream Cheese Rollups.txt
# Make Ahead French Toast.txt
# Mexican Shrimp Cocktail.txt
# Mini Ham And Cheese Rolls.txt
# Monkey Bread I.txt
# Microwave Popcorn.txt
# Monkey Bread V.txt
# Mom_s Zucchini Bread.txt
# Mom_s Best Waffles.txt
# Mom_s Applesauce Pancakes.txt
# Monkey Bread II.txt
# Mom_s Buttermilk Pancakes.txt
# Monte Cristo Sandwich - the Real One.txt
# Mouth-Watering Stuffed Mushrooms.txt
# Mother_s Banana Bread.txt
# Nacho Cheese Sauce.txt
# Oatmeal Banana Nut Bread.txt
# My Crab Cakes.txt
# Oatmeal and Wheat Flour Blueberry Pancakes.txt
# Oatmeal Pancakes II.txt
# No-Bake Energy Bites.txt
# My-Hop Pancakes.txt
# Old Charleston Style Shrimp and Grits.txt
# Original Chex® Party Mix.txt
# Overnight Apple Cinnamon French Toast.txt
# Old Fashioned Coconut Cream Pie.txt
# Oven Scrambled Eggs.txt
# Oyster and Cornbread Dressing.txt
# Omelet in a Bag.txt
# Old-Fashioned Pancakes.txt
# Overnight Blueberry French Toast.txt
# Orange Pecan French Toast.txt
# Pancakes I.txt
# Peanut Butter Banana Smoothie.txt
# Peanut Butter Bars I.txt
# Panettone French Toast.txt
# Peanut Butter Cup Cookies.txt
# Party Pinwheels.txt
# Parmesan Spinach Balls.txt
# Pecan Pie V.txt
# Perfect Pressure Cooker Pot Roast.txt
# Pancakes.txt
# Perfect Pumpkin Pie.txt
# Pine Cone Cheese Ball.txt
# Perfect Turkey.txt
# Potato Chips.txt
# Pesto Puff Pastry Pinwheel.txt
# Pico De Gallo.txt
# Perfect Sushi Rice.txt
# Playgroup Granola Bars.txt
# Pork Dumplings.txt
# Pita Chips.txt
# Potato Skillet.txt
# Pumpkin Fluff Dip .txt
# Quiche Lorraine I.txt
# Puppy Chow I.txt
# Pumpkin Pie Bread.txt
# Pumpkin Pancakes.txt
# Pumpkin Dip.txt
# Pumpkin Waffles with Apple Cider Syrup.txt
# Pumpkin Bread IV.txt
# Pumpkin Spiced Latte.txt
# Quiche.txt
# Real Hummus.txt
# Ranch Oyster Crackers.txt
# Quick and Easy Home Fries.txt
# Reuben Dip.txt
# Quick Quiche.txt
# Restaurant-Style Potato Skins.txt
# Quick Baked Zucchini Chips.txt
# Quick and Easy Brownies.txt
# Quick Asian Lettuce Wraps .txt
# Rich and Delicious Banana Bread.txt
# Sausage Balls.txt
# Roasted Grape Crostini with Fresh Herbs.txt
# Roasted Brussels Sprouts.txt
# Rockin_ Salsa.txt
# Roasted Pumpkin Seeds.txt
# Roasted Garlic Bread.txt
# Roasted Chickpeas.txt
# Sausage Brunch Casserole.txt
# Sausage Casserole.txt
# Sausage Egg Casserole.txt
# Sausage Jalapeno Poppers.txt
# Seven Layer Taco Dip.txt
# Savory Crab Stuffed Mushrooms.txt
# Seven Layer Dip I.txt
# Seven Layer Dip II.txt
# Sausage, Peppers, Onions, and Potato Bake.txt
# Scrambled Egg Muffins.txt
# Scrambled Eggs Done Right.txt
# Sausage Stuffed Jalapenos.txt
# Shrimp Artichoke Dip.txt
# Southern Grits Casserole.txt
# Slow Cooker Pot Roast.txt
# Slow Cooker Green Bean Casserole.txt
# Slow Cooker Reuben Dip.txt
# Slow Cooker Stuffing.txt
# Slow Cooker Pork Loin Roast with Brown Sugar and Sweet Potatoes.txt
# Slow Cooker Steak Fajitas.txt
# Simple Roasted Butternut Squash.txt
# Slow Cooker Beef Stew I.txt
# Southern Pimento Cheese.txt
# Spinach and Artichoke Dip.txt
# Spinach and Potato Frittata.txt
# Spanakopita II.txt
# Spiced Pumpkin Seeds.txt
# Spicy Tortilla Roll-Ups.txt
# Spicy Bean Salsa.txt
# Spiced Sweet Roasted Red Pepper Hummus.txt
# Spinach and Cheese Pie.txt
# Special Deviled Eggs.txt
# Spinach Brownies.txt
# Stuffed Jalapenos III.txt
# Stovetop Granola.txt
# Spinach Quiche.txt
# Sunday Morning Lemon Poppy Seed Pancakes.txt
# Strawberry Bread.txt
# Strawberry Vanilla Pancakes.txt
# Strawberry Oatmeal Breakfast Smoothie.txt
# Spinach Quiche with Cottage Cheese.txt
# Sugar Coated Pecans.txt
# Sunshine Toast.txt
# Sweet and Sour Sauce II.txt
# Super Moist Pumpkin Bread.txt
# Taco Bake I.txt
# Taco Dip I.txt
# Swedish Saffron Buns.txt
# Tater Tot Casserole I.txt
# Sweet, Salty, Spicy Party Nuts.txt
# Sweet and Sour Meatballs.txt
# Sweet Potato Pie I.txt
# Tender and Easy Buttermilk Waffles.txt
# Texas Caviar I.txt
# Toasted Pumpkin Seeds with Sugar and Spice.txt
# The Best Fresh Tomato Salsa.txt
# Tomatillo Salsa Verde.txt
# The Best Sweet and Sour Meatballs.txt
# Tomato and Mozzarella Bites.txt
# Todd_s Famous Blueberry Pancakes.txt
# The Best Rolled Sugar Cookies.txt
# Toasted Garlic Bread.txt
# Traditional Filipino Lumpia.txt
# Uglies.txt
# Vanilla Crepes.txt
# Vietnamese Fresh Spring Rolls.txt
# Vicki_s Hush Puppies.txt
# Veronica_s Hot Spinach, Artichoke and Chile Dip.txt
# Vegan Pancakes.txt
# Turkey Brine.txt
# Veronica_s Apple Pancakes.txt
# Truck-Stop Buttermilk Pancakes.txt
# Waffles I.txt
# Whole Wheat Pancakes.txt
# Whole Wheat Blueberry Pancakes.txt
# Wheat Germ Whole-Wheat Buttermilk Pancakes.txt
# Whole Grain Waffles.txt
# Waffles II.txt
# Whole Grain Breakfast Cookies.txt
# Warm Crab Parmesan Dip.txt
# Watermelon Fire and Ice Salsa.txt
# Whole Wheat Banana Nut Bread.txt
# Whole Wheat, Oatmeal, and Banana Pancakes.txt
# World_s Best Lasagna.txt
# Zesty Porcupine Meatballs.txt
# Wild Rice Stuffed Acorn Squash .txt
# Yeast-Free Cinnamon Rolls.txt
# Yummy Roll Ups.txt
# Yummy Sweet Potato Casserole.txt
# Zucchini Bread IV.txt
# Zucchini Bread.txt

# %%
food_df1
# Out:
#                                     Recipe_file  ...                                        Ingredients
# 0           15-Minute Dinner Nachos Supreme.txt  ...  [beef, tomato, soup, water, ricepace®, salsash...
# 1                         Antipasto Squares.txt  ...  [sliced, boiled, ham, cheese, pepperoni, sausa...
# 2    Annie_s Fruit Salsa and Cinnamon Chips.txt  ...  [fruit, salsa, cinnamon, chips, kiwis, diced, ...
# 3                Amy_s Cilantro Cream Sauce.txt  ...  [cilantro, cream, sauce, cheese, salsa, pepper...
# 4                     Apple Breakfast Bread.txt  ...  [apple, bread, butter, sugar, eggs, flour, sod...
# ..                                          ...  ...                                                ...
# 464               Yeast-Free Cinnamon Rolls.txt  ...  [yeastfree, cinnamon, flour, sugar, powder, so...
# 465                          Yummy Roll Ups.txt  ...  [slices, ham, cream, cheese, dill, pickle, spe...
# 466            Yummy Sweet Potato Casserole.txt  ...  [potato, sugar, eggs, salt, butter, milk, vani...
# 467                       Zucchini Bread IV.txt  ...  [zucchini, bread, eggs, vegetable, oil, sugar,...
# 468                          Zucchini Bread.txt  ...  [zucchini, bread, flour, eggs, sugar, vegetabl...
#
# [469 rows x 3 columns]

# %% [markdown]
# ## Appending all dataframes

# %%
food_df=food_df.append(food_df1)

# %%
food_df
# Out:
#                                Recipe_file  ...                                        Ingredients
# 0             asparagus-pistachio-soup.txt  ...  [soup, salt, salted, pistachios, butter, salty...
# 1                      aubergine_puree.txt  ...  [aubergine, aubergines, peppers, tomatoes, clo...
# 2                         clam_chowder.txt  ...  [potatoes, potato, floury, boiled, bacon, pork...
# 3                    easy_pumpkin_soup.txt  ...                               [pumpkin, butternut]
# 4    beans_midly_spiced_and_stir-fried.txt  ...  [beans, spiced, turmeric, powder, curry, leave...
# ..                                     ...  ...                                                ...
# 464          Yeast-Free Cinnamon Rolls.txt  ...  [yeastfree, cinnamon, flour, sugar, powder, so...
# 465                     Yummy Roll Ups.txt  ...  [slices, ham, cream, cheese, dill, pickle, spe...
# 466       Yummy Sweet Potato Casserole.txt  ...  [potato, sugar, eggs, salt, butter, milk, vani...
# 467                  Zucchini Bread IV.txt  ...  [zucchini, bread, eggs, vegetable, oil, sugar,...
# 468                     Zucchini Bread.txt  ...  [zucchini, bread, flour, eggs, sugar, vegetabl...
#
# [501 rows x 3 columns]

# %%
len(food_df)
# Out:
# 501

# %% [markdown]
# ## Creating train and test data

# %%
train_size = int(len(food_df) * .8)
train_posts = food_df['Ingredients']
train_tags = food_df['Recipe']
train_files_names = food_df['Recipe_file']
 
test_posts = food_df['Ingredients'][train_size:]
test_tags = food_df['Recipe'][train_size:]
test_files_names = food_df['Recipe_file'][train_size:]

# %%
len(train_tags)
# Out:
# 501

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_posts)
 
x_train = tokenizer.texts_to_matrix(train_posts, mode='tfidf')
x_test = tokenizer.texts_to_matrix(test_posts, mode='tfidf')
 
encoder = LabelBinarizer()
encoder.fit(train_tags)
y_train = encoder.transform(train_tags)
y_test = encoder.transform(test_tags)

# %% [markdown]
# ## Creating input and output shape for Neural-Network Model

# %%
vocab_size = x_train.shape[1]
print(vocab_size)
# Out:
# 422

# %%
num_labels = y_train.shape[1]
num_labels
# Out:
# 501

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((501, 422), (501, 501), (101, 422), (101, 501))

# %% [markdown]
# ## Function to plot loss and accuracy

# %%
# Function to plot the statistics
def plot_history(history):
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

# %% [markdown]
# ## Model Architecture

# %%
model = Sequential()
model.add(Dense(512, input_shape=(vocab_size,)))
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(num_labels))
model.add(Activation('softmax'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               216576
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# activation_2 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 501)               257013
# _________________________________________________________________
# activation_3 (Activation)    (None, 501)               0
# =================================================================
# Total params: 736,245
# Trainable params: 736,245
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Loss and optimiser for model

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %% [markdown]
# ## Model Training

# %%
history = model.fit(x_train, y_train,
                    batch_size=10,
                    epochs=30,
                    verbose=1,
                    validation_split=0.1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 450 samples, validate on 51 samples
# Epoch 1/30
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 450/450 [==============================] - 5s 11ms/step - loss: 6.4413 - acc: 0.0000e+00 - val_loss: 6.5014 - val_acc: 0.0000e+00
# Epoch 2/30
# 450/450 [==============================] - 0s 400us/step - loss: 5.6710 - acc: 0.1356 - val_loss: 7.4490 - val_acc: 0.0000e+00
# Epoch 3/30
# 450/450 [==============================] - 0s 404us/step - loss: 4.2042 - acc: 0.3778 - val_loss: 8.8165 - val_acc: 0.0000e+00
# Epoch 4/30
# 450/450 [==============================] - 0s 435us/step - loss: 2.0784 - acc: 0.6733 - val_loss: 10.2870 - val_acc: 0.0000e+00
# Epoch 5/30
# 450/450 [==============================] - 0s 422us/step - loss: 0.8865 - acc: 0.8578 - val_loss: 11.9231 - val_acc: 0.0000e+00
# Epoch 6/30
# 450/450 [==============================] - 0s 399us/step - loss: 0.5206 - acc: 0.9044 - val_loss: 12.3684 - val_acc: 0.0000e+00
# Epoch 7/30
# 450/450 [==============================] - 0s 373us/step - loss: 0.2945 - acc: 0.9556 - val_loss: 13.0534 - val_acc: 0.0000e+00
# Epoch 8/30
# 450/450 [==============================] - 0s 376us/step - loss: 0.2493 - acc: 0.9422 - val_loss: 13.1921 - val_acc: 0.0000e+00
# Epoch 9/30
# 450/450 [==============================] - 0s 357us/step - loss: 0.2019 - acc: 0.9622 - val_loss: 13.3578 - val_acc: 0.0000e+00
# Epoch 10/30
# 450/450 [==============================] - 0s 393us/step - loss: 0.1638 - acc: 0.9600 - val_loss: 13.3769 - val_acc: 0.0000e+00
# Epoch 11/30
# 450/450 [==============================] - 0s 373us/step - loss: 0.1360 - acc: 0.9711 - val_loss: 13.5945 - val_acc: 0.0000e+00
# Epoch 12/30
# 450/450 [==============================] - 0s 385us/step - loss: 0.1320 - acc: 0.9756 - val_loss: 13.6821 - val_acc: 0.0000e+00
# Epoch 13/30
# 450/450 [==============================] - 0s 365us/step - loss: 0.0848 - acc: 0.9867 - val_loss: 13.9760 - val_acc: 0.0000e+00
# Epoch 14/30
# 450/450 [==============================] - 0s 363us/step - loss: 0.0753 - acc: 0.9867 - val_loss: 14.0085 - val_acc: 0.0000e+00
# Epoch 15/30
# 450/450 [==============================] - 0s 365us/step - loss: 0.0788 - acc: 0.9822 - val_loss: 14.1769 - val_acc: 0.0000e+00
# Epoch 16/30
# 450/450 [==============================] - 0s 385us/step - loss: 0.0691 - acc: 0.9822 - val_loss: 14.1175 - val_acc: 0.0000e+00
# Epoch 17/30
# 450/450 [==============================] - 0s 368us/step - loss: 0.0642 - acc: 0.9911 - val_loss: 13.9835 - val_acc: 0.0000e+00
# Epoch 18/30
# 450/450 [==============================] - 0s 424us/step - loss: 0.0410 - acc: 0.9956 - val_loss: 14.3763 - val_acc: 0.0000e+00
# Epoch 19/30
# 450/450 [==============================] - 0s 370us/step - loss: 0.0295 - acc: 0.9956 - val_loss: 14.5413 - val_acc: 0.0000e+00
# Epoch 20/30
# 450/450 [==============================] - 0s 395us/step - loss: 0.0554 - acc: 0.9844 - val_loss: 14.5098 - val_acc: 0.0000e+00
# Epoch 21/30
# 450/450 [==============================] - 0s 430us/step - loss: 0.0323 - acc: 0.9911 - val_loss: 14.5552 - val_acc: 0.0000e+00
# Epoch 22/30
# 450/450 [==============================] - 0s 383us/step - loss: 0.0341 - acc: 0.9933 - val_loss: 14.5841 - val_acc: 0.0000e+00
# Epoch 23/30
# 450/450 [==============================] - 0s 392us/step - loss: 0.0297 - acc: 0.9889 - val_loss: 14.6354 - val_acc: 0.0000e+00
# Epoch 24/30
# 450/450 [==============================] - 0s 361us/step - loss: 0.0314 - acc: 0.9956 - val_loss: 14.7663 - val_acc: 0.0000e+00
# Epoch 25/30
# 450/450 [==============================] - 0s 356us/step - loss: 0.0321 - acc: 0.9978 - val_loss: 14.7931 - val_acc: 0.0000e+00
# Epoch 26/30
# 450/450 [==============================] - 0s 421us/step - loss: 0.0398 - acc: 0.9933 - val_loss: 14.7638 - val_acc: 0.0000e+00
# Epoch 27/30
# 450/450 [==============================] - 0s 439us/step - loss: 0.0282 - acc: 0.9889 - val_loss: 14.6795 - val_acc: 0.0000e+00
# Epoch 28/30
# 450/450 [==============================] - 0s 380us/step - loss: 0.0501 - acc: 0.9867 - val_loss: 14.5448 - val_acc: 0.0000e+00
# Epoch 29/30
# 450/450 [==============================] - 0s 393us/step - loss: 0.0350 - acc: 0.9911 - val_loss: 14.6205 - val_acc: 0.0000e+00
# Epoch 30/30
# 450/450 [==============================] - 0s 384us/step - loss: 0.0361 - acc: 0.9889 - val_loss: 14.5314 - val_acc: 0.0000e+00

# %% [markdown]
# ## Loss,Accuracy plots

# %%
loss, accuracy = model.evaluate(x_train, y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(x_test, y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
plot_history(history)
# Out:
# Training Accuracy: 0.8962
# Testing Accuracy:  0.4950

# %% [markdown]
# ## Preparing data to test

# %%
text_labels = encoder.classes_

# %%
text_labels
# Out:
# array(['15-Minute Dinner Nachos Supreme', '4H Banana Bread',
#        'Ali_s Amazing Bruschetta', 'All-Around Good Smoothie',
#        'Amazing Muffin Cups', 'Amy_s Cilantro Cream Sauce',
#        'Annie_s Fruit Salsa and Cinnamon Chips', 'Antipasto Squares',
#        'Apple Breakfast Bread', 'Apple Crisp II', 'Apple Dip',
#        'Apple Pie by Grandma Ople', 'Apple Raisin French Toast Strata',
#        'Apple-Raisin French Toast Casserole', 'Arizona Hatch Chili',
#        'Arlene_s Bacon _ Crabmeat', 'Artichoke Bruschetta',
#        'Artichoke Spinach Dip',
#        'Artichoke _ Spinach Dip Restaurant Style', 'Asian Lettuce Wraps',
#        'Asparagus Quiche', 'Avocado Corn Salsa', 'Avocado Feta Salsa',
#        'Avocado, Tomato and Mango Salsa',
#        'Awesome Sausage, Apple and Cranberry Stuffing',
#        'Awesome and Easy Creamy Corn Casserole',
#        'B and L_s Strawberry Smoothie', 'BLT Dip', 'Ba_corn Cheese Corn ',
#        'Baba Ghanoush', 'Baby BLT', 'Baby Spinach Omelet',
#        'Bacon Cheddar Deviled Eggs', 'Bacon Quiche Tarts',
#        'Bacon Water Chestnut Rolls', 'Bacon Wrapped Barbeque Shrimp',
#        'Bacon Wrapped Dates Stuffed with Blue Cheese',
#        'Bacon Wrapped Smokies', 'Bacon and Cheddar Stuffed Mushrooms',
#        'Bacon and Tomato Cups', 'Bacon for the Family or a Crowd',
#        'Bacon-Wrapped Jalapeno Poppers', 'Baked Denver Omelet',
#        'Baked French Toast', 'Baked Ham and Cheese Party Sandwiches',
#        'Baked Kale Chips', 'Baked Oatmeal I', 'Baked Oatmeal II',
#        'Baked Omelet', 'Baked Omelet Roll', 'Baked Omelet Squares',
#        'Baked Pork Spring Rolls', 'Baked Tortilla Chips',
#        'Balsamic Bruschetta', 'Banana Banana Bread', 'Banana Bread',
#        'Banana Bread - Quick Bread for Machines', 'Banana Crepes',
#        'Banana Nut Bread I', 'Banana Nut Bread II', 'Banana Pancakes I',
#        'Banana Peanut Butter Bread', 'Banana Sour Cream Bread',
#        'Basic Crepes', 'Basic Mashed Potatoes', 'Beef Stew VI',
#        'Best Big, Fat, Chewy Chocolate Chip Cookie', 'Best Brownies',
#        'Best Bruschetta Ever', 'Best Chocolate Chip Cookies',
#        'Best Egg Rolls', 'Best Ever Jalapeno Poppers',
#        'Best Ever Slow Cooker Italian Beef Roast',
#        'Best Green Bean Casserole', 'Best Guacamole',
#        'Best Potatoes You_ll Ever Taste', 'Best Spinach Dip Ever',
#        'Better-Than-Olive Garden® Alfredo Sauce ', 'Black Bean Hummus',
#        'Blooming Onion and Dipping Sauce', 'Blue Bacon Stuffed Mushrooms',
#        'Blueberry French Toast', 'Boilermaker Tailgate Chili',
#        'Breakfast Casserole II', 'Breakfast Casserole III',
#        'Breakfast Pies', 'Brie Cheese Appetizer', 'Broiled Grapefruit',
#        'Brown Sugar Banana Nut Bread I', 'Brown Sugar Smokies',
#        'Brunch Enchiladas', 'Brussels Sprouts Gratin',
#        'Butter Flaky Pie Crust', 'Buttermilk Pancakes I',
#        'Buttermilk Pancakes II', 'Candied Almonds', 'Candied Pecans ',
#        'Candied Yams', 'Candy Coated Pecans', 'Caramel Apple Pork Chops',
#        'Caramel Snack Mix', 'Carla_s Fruit Dip', 'Cathy_s Banana Bread',
#        'Charleston Breakfast Casserole', 'Cheddar Bay Biscuits',
#        'Cheese Ball I', 'Cheese Fondue',
#        'Cheesy Amish Breakfast Casserole',
#        'Cheesy Broccoli-Stuffed Chicken Breasts',
#        'Cheesy Ham and Hash Brown Casserole',
#        'Cheesy Sausage Lasagna Soup', 'Chef John_s Baked Eggs',
#        'Chef John_s Banana Bread', 'Chef John_s Make-Ahead Turkey Gravy',
#        'Chef John_s Pumpkin Pancakes', 'Chef John_s Pumpkin Pie',
#        'Chef John_s Quiche Lorraine', 'Chef John_s Shepherd_s Pie',
#        'Chewy Granola Bars', 'Chicago Dip', 'Chocolate Chip Cheese Ball',
#        'Chocolate Chip Orange Zucchini Bread', 'Chocolate Eclair Cake',
#        'Chocolate Kahlua® Cake', 'Chocolate Wave Zucchini Bread',
#        'Christmas Breakfast Pizza',
#        'Christmas Breakfast Sausage Casserole',
#        'Christmas Brunch Casserole', 'Chunky Monkey Pancakes',
#        'Cinnamon Bread I', 'Cinnamon Griddle Cakes',
#        'Cinnamon Raisin Bread I', 'Cinnamon Swirl Bread',
#        'Clark_s Quiche', 'Classic Waffles', 'Cocktail Meatballs',
#        'Cocktail Meatballs I', 'Coconut Shrimp I', 'Corn Fritters',
#        'Country Breakfast Casserole', 'Country Quiche',
#        'Country Style Fried Potatoes', 'Crab Dip', 'Crab Quiche',
#        'Crab Quiche I', 'Crab Rangoon III', 'Crab Stuffed Mushrooms',
#        'Crab and Swiss Quiche', 'Cranberry Orange Rolls',
#        'Cranberry Sauce', 'Cream Cheese Penguins',
#        'Cream Corn Like No Other', 'Creamy Banana Bread',
#        'Creamy Cornbread Casserole ', 'Creamy Dill Cucumber Toasties',
#        'Creamy Mushroom Meatloaf', 'Creamy Strawberry Crepes',
#        'Creme Brulee French Toast', 'Crepes',
#        'Crock Pot® Party Meatballs', 'Crustless Spinach Quiche',
#        'D_s Famous Salsa', 'Danish Kringle', 'Dawn_s Candied Walnuts',
#        'Delicious Ham and Potato Soup', 'Delicious Pumpkin Bread',
#        'Dessert Crepes', 'Deviled Eggs', 'Deviled Eggs I',
#        'Deviled Eggs II', 'Di_s Delicious Deluxe Deviled Eggs',
#        'Dill Dip III', 'Dinah_s Stuffed Mushrooms', 'Dip For The Stars',
#        'Divine Hard-Boiled Eggs', 'Dominican Style Oatmeal',
#        'Double Layer Pumpkin Cheesecake', 'Double Tomato Bruschetta',
#        'Downeast Maine Pumpkin Bread', 'Dutch Babies II',
#        'Easter Breakfast Casserole', 'Easy Bacon and Cheese Quiche',
#        'Easy Banana Bread', 'Easy Cheese Ball II', 'Easy Granola Bars',
#        'Easy Guacamole', 'Easy Homemade Pie Crust', 'Easy Hummus',
#        'Easy Meatloaf', 'Easy Pancakes', 'Easy Quiche',
#        'Easy Quiche Lorraine', 'Easy Roasted Red Pepper Hummus',
#        'Easy Sausage Gravy and Biscuits', 'Easy Sausage Strata',
#        'Easy Spicy Roasted Potatoes', 'Egg and Sausage Casserole',
#        'Egg in a Hole', 'Eggs Benedict', 'Eggs Benedict Casserole',
#        'Emma_s Belgian Waffles',
#        'Espinacas con Garbanzos (Spinach with Garbanzo Beans)',
#        'Extra Easy Hummus', 'Farmer_s Casserole',
#        'Fast and Easy Pancakes', 'Favorite Banana Blueberry Quick Bread',
#        'Feta Cheese Foldovers', 'Florentine Artichoke Dip',
#        'Fluffy Canadian Pancakes', 'Fluffy French Toast',
#        'Fluffy Pancakes', 'Fluffy and Delicious Pancakes',
#        'French Crepes', 'French Onion Casserole',
#        'French Toast Casserole', 'French Toast I', 'French Toast II',
#        'French Toast Souffle', 'Fresh Tomato Salsa',
#        'Fried Cabbage with Bacon, Onion, and Garlic',
#        'Fried Mozzarella Cheese Sticks', 'Fruit Dip II',
#        'Gary_s Stuffed Mushrooms', 'German Apple Pancake',
#        'German Pancakes II', 'German Potato Pancakes',
#        'Gingerbread Waffles with Hot Chocolate Sauce',
#        'Good Old Fashioned Pancakes', 'Gourmet Sweet Potato Classic',
#        'Grain and Nut Whole Wheat Pancakes', 'Grandad_s Pancakes',
#        'Grandma_s Corn Bread Dressing', 'Grandma_s Green Bean Casserole',
#        'Grandma_s Peach French Toast',
#        'Grandmother_s Buttermilk Cornbread',
#        'Grandpa_s Classic Coney Sauce', 'Granola Bars III',
#        'Great Garlic Bread', 'Grilled Bacon Jalapeno Wraps',
#        'Grilled Marinated Shrimp', 'Grilled Portobello Mushrooms',
#        'Grilled Shrimp Scampi', 'Groovy Green Smoothie', 'Guacamole',
#        'Ham and Cheese Breakfast Quiche', 'Ham and Cheese Quiche',
#        'Hamburger Steak with Onions and Gravy', 'Hash Brown Quiche',
#        'Hash Brown and Egg Casserole',
#        'Healthier Mediterranean Tuna Salad',
#        'Heather_s Cilantro, Black Bean, and Corn Salsa',
#        'Home-Fried Potatoes', 'Homemade Butter', 'Honey Butter',
#        'Honey Mustard Sauce', 'Honey Nut Granola',
#        'Hot Artichoke Spinach Dip', 'Hot Artichoke and Spinach Dip II',
#        'Hot Bean Dip', 'Hot Crab Dip', 'Hot Mexican Spinach Dip',
#        'Hot Pizza Dip', 'How to Cook a Turkey', 'Hummus III',
#        'Hungarian Mushroom Soup', 'Individual Baked Eggs',
#        'Instant Pot® Turkey Breast', 'Irish Soda Bread I',
#        'Irresistible Irish Soda Bread',
#        'Italian Sausage Soup with Tortellini', 'Jalapeno Popper Spread',
#        'Jalapeno Poppers I', 'Janet_s Rich Banana Bread',
#        'Jimmy Dean Breakfast Casserole',
#        'Joseph_s Best Easy Bacon Recipe', 'Joy_s Easy Banana Bread',
#        'Juicy Thanksgiving Turkey',
#        'Ken_s Perfect Hard Boiled Egg (And I Mean Perfect)',
#        'Kettle Corn', 'Kielbasa and Potato Bake',
#        'Kielbasa with Brussels Sprouts', 'King Crab Appetizers',
#        'Lana_s Sweet and Sour Meatballs', 'Libby_s® Famous Pumpkin Pie',
#        'Light and Fluffy Spinach Quiche', 'Loaded Crack Potatoes',
#        'Lola_s Horchata', 'Louisiana Sweet Potato Pancakes',
#        'Lower Fat Banana Bread I', 'Lower Fat Banana Bread II',
#        'Luscious Spinach Artichoke Dip', 'Make Ahead Breakfast Casserole',
#        'Make Ahead French Toast', 'Make-Ahead Turkey Gravy',
#        'Mango Salsa', 'Maple Apple Turkey Sausage',
#        'Mary_s Roasted Red Pepper Dip', 'Maryland Crab Cakes II',
#        'Megan_s Granola', 'Mexican Cream Cheese Rollups',
#        'Mexican Shrimp Cocktail', 'Microwave Popcorn',
#        'Mini Ham And Cheese Rolls', 'Mom_s Applesauce Pancakes',
#        'Mom_s Best Waffles', 'Mom_s Buttermilk Pancakes',
#        'Mom_s Zucchini Bread', 'Monkey Bread I', 'Monkey Bread II',
#        'Monkey Bread V', 'Monte Cristo Sandwich - the Real One',
#        'Mother_s Banana Bread', 'Mouth-Watering Stuffed Mushrooms',
#        'My Crab Cakes', 'My-Hop Pancakes', 'Nacho Cheese Sauce',
#        'No-Bake Energy Bites', 'Oatmeal Banana Nut Bread',
#        'Oatmeal Pancakes II',
#        'Oatmeal and Wheat Flour Blueberry Pancakes',
#        'Old Charleston Style Shrimp and Grits',
#        'Old Fashioned Coconut Cream Pie', 'Old-Fashioned Pancakes',
#        'Omelet in a Bag', 'Orange Pecan French Toast',
#        'Original Chex® Party Mix', 'Oven Scrambled Eggs',
#        'Overnight Apple Cinnamon French Toast',
#        'Overnight Blueberry French Toast',
#        'Oyster and Cornbread Dressing', 'Pancakes', 'Pancakes I',
#        'Panettone French Toast', 'Parmesan Spinach Balls',
#        'Party Pinwheels', 'Peanut Butter Banana Smoothie',
#        'Peanut Butter Bars I', 'Peanut Butter Cup Cookies', 'Pecan Pie V',
#        'Perfect Pressure Cooker Pot Roast', 'Perfect Pumpkin Pie',
#        'Perfect Sushi Rice', 'Perfect Turkey',
#        'Pesto Puff Pastry Pinwheel', 'Pico De Gallo',
#        'Pine Cone Cheese Ball', 'Pita Chips', 'Playgroup Granola Bars',
#        'Pork Dumplings', 'Potato Chips', 'Potato Skillet',
#        'Pumpkin Bread IV', 'Pumpkin Dip', 'Pumpkin Fluff Dip ',
#        'Pumpkin Pancakes', 'Pumpkin Pie Bread', 'Pumpkin Spiced Latte',
#        'Pumpkin Waffles with Apple Cider Syrup', 'Puppy Chow I', 'Quiche',
#        'Quiche Lorraine I', 'Quick Asian Lettuce Wraps ',
#        'Quick Baked Zucchini Chips', 'Quick Quiche',
#        'Quick and Easy Brownies', 'Quick and Easy Home Fries',
#        'Ranch Oyster Crackers', 'Real Hummus',
#        'Restaurant-Style Potato Skins', 'Reuben Dip',
#        'Rich and Delicious Banana Bread', 'Roasted Brussels Sprouts',
#        'Roasted Chickpeas', 'Roasted Garlic Bread',
#        'Roasted Grape Crostini with Fresh Herbs', 'Roasted Pumpkin Seeds',
#        'Rockin_ Salsa', 'Sausage Balls', 'Sausage Brunch Casserole',
#        'Sausage Casserole', 'Sausage Egg Casserole',
#        'Sausage Jalapeno Poppers', 'Sausage Stuffed Jalapenos',
#        'Sausage, Peppers, Onions, and Potato Bake',
#        'Savory Crab Stuffed Mushrooms', 'Scrambled Egg Muffins',
#        'Scrambled Eggs Done Right', 'Seven Layer Dip I',
#        'Seven Layer Dip II', 'Seven Layer Taco Dip',
#        'Shrimp Artichoke Dip', 'Simple Roasted Butternut Squash',
#        'Slow Cooker Beef Stew I', 'Slow Cooker Green Bean Casserole',
#        'Slow Cooker Pork Loin Roast with Brown Sugar and Sweet Potatoes',
#        'Slow Cooker Pot Roast', 'Slow Cooker Reuben Dip',
#        'Slow Cooker Steak Fajitas', 'Slow Cooker Stuffing',
#        'Southern Grits Casserole', 'Southern Pimento Cheese',
#        'Spanakopita II', 'Special Deviled Eggs', 'Spiced Pumpkin Seeds',
#        'Spiced Sweet Roasted Red Pepper Hummus', 'Spicy Bean Salsa',
#        'Spicy Tortilla Roll-Ups', 'Spinach Brownies', 'Spinach Quiche',
#        'Spinach Quiche with Cottage Cheese', 'Spinach and Artichoke Dip',
#        'Spinach and Cheese Pie', 'Spinach and Potato Frittata',
#        'Stovetop Granola', 'Strawberry Bread',
#        'Strawberry Oatmeal Breakfast Smoothie',
#        'Strawberry Vanilla Pancakes', 'Stuffed Jalapenos III',
#        'Sugar Coated Pecans', 'Sunday Morning Lemon Poppy Seed Pancakes',
#        'Sunshine Toast', 'Super Moist Pumpkin Bread',
#        'Swedish Saffron Buns', 'Sweet Potato Pie I',
#        'Sweet and Sour Meatballs', 'Sweet and Sour Sauce II',
#        'Sweet, Salty, Spicy Party Nuts', 'Taco Bake I', 'Taco Dip I',
#        'Tater Tot Casserole I', 'Tender and Easy Buttermilk Waffles',
#        'Texas Caviar I', 'The Best Fresh Tomato Salsa',
#        'The Best Rolled Sugar Cookies',
#        'The Best Sweet and Sour Meatballs', 'Toasted Garlic Bread',
#        'Toasted Pumpkin Seeds with Sugar and Spice',
#        'Todd_s Famous Blueberry Pancakes', 'Tomatillo Salsa Verde',
#        'Tomato and Mozzarella Bites', 'Traditional Filipino Lumpia',
#        'Truck-Stop Buttermilk Pancakes', 'Turkey Brine', 'Uglies',
#        'Vanilla Crepes', 'Vegan Pancakes', 'Veronica_s Apple Pancakes',
#        'Veronica_s Hot Spinach, Artichoke and Chile Dip',
#        'Vicki_s Hush Puppies', 'Vietnamese Fresh Spring Rolls',
#        'Waffles I', 'Waffles II', 'Warm Crab Parmesan Dip',
#        'Watermelon Fire and Ice Salsa',
#        'Wheat Germ Whole-Wheat Buttermilk Pancakes',
#        'Whole Grain Breakfast Cookies', 'Whole Grain Waffles',
#        'Whole Wheat Banana Nut Bread', 'Whole Wheat Blueberry Pancakes',
#        'Whole Wheat Pancakes',
#        'Whole Wheat, Oatmeal, and Banana Pancakes',
#        'Wild Rice Stuffed Acorn Squash ', 'World_s Best Lasagna',
#        'Yeast-Free Cinnamon Rolls', 'Yummy Roll Ups',
#        'Yummy Sweet Potato Casserole', 'Zesty Porcupine Meatballs',
#        'Zucchini Bread', 'Zucchini Bread IV', 'asparagus-pistachio-soup',
#        'aubergine_puree', 'basque-style_cream_mushroom_soup_saveur',
#        'beans_midly_spiced_and_stir-fried', 'clam_chowder', 'dolmeh',
#        'easy_grilled_leeks_with_grated_cheese', 'easy_microwave_tomato',
#        'easy_pumpkin_soup', 'grilled_onions', 'healthy_asian_apple_soup',
#        'hoomos', 'hot_and_sour_cucumbers', 'hot_and_sour_shrimp_soup',
#        'kapustniak', 'kapustnica_sour_cabbage_soup', 'kimchi', 'latkes',
#        'lettuce_soup', 'madjara', 'mango', 'mechthilds_sweet_potatoes',
#        'monastery_style_bean_soup', 'oyster_stew', 'potato-turnip_balls',
#        'quick_and_dirty', 'reasted_red_onion_soup',
#        'sopa_de_carbasso_bercelonia', 'southwestern_onion_soup',
#        'stuffed_aubergines', 'stuffed_peppers_with_egg_and_cheese',
#        'sweet_red_pepper_soup'], dtype='<U63')

# %% [markdown]
# ## Dummy data arrays

# %%
a=['apples','bananas','eggs', 'tomato','lettuce', 'ham', 'creme', 'eggs', 'creamy', 'nicely']

# %%
b=['bean', 'chillies', 'choice', 'mint','tahiini', 'garbanzos', 'sesame']

# %% [markdown]
# ## Function to predict recipe by taking ingredient as input

# %%
def recipe_suggestor(ingredients):
  n=len(ingredients)
  interim_results = tokenizer.texts_to_matrix(ingredients,mode='tfidf')
  prediction = model.predict(np.array(interim_results))
  pred_label=[]
  for i in range(n):
    predicted_label = text_labels[np.argmax(prediction[i])]
    pred_label.append(predicted_label)
  Result=set(pred_label)
  Result=list(Result)
  return Result

# %% [markdown]
# ## Results

# %%
recipe_suggestor(a)
# Out:
# ['easy_microwave_tomato',
#  'German Apple Pancake',
#  'Carla_s Fruit Dip',
#  'Awesome and Easy Creamy Corn Casserole',
#  'Banana Pancakes I',
#  'French Toast Souffle',
#  'Ham and Cheese Breakfast Quiche',
#  'lettuce_soup']

# %%
recipe_suggestor(b)
# Out:
# ['hoomos', 'monastery_style_bean_soup', 'Best Green Bean Casserole']
